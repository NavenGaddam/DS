# %%
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
airline_data = pd.read_excel("EastWestAirlines.xlsx", sheet_name='data')
airline_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_data.rename(columns={'ID#': 'UniqueID', 'Award?': 'Award'}, inplace=True)
airline_data
# Out:
#       UniqueID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0            1    28143           0          1          1          1
# 1            2    19244           0          1          1          1
# 2            3    41354           0          1          1          1
# 3            4    14776           0          1          1          1
# 4            5    97752           0          4          1          1
# ...        ...      ...         ...        ...        ...        ...
# 3994      4017    18476           0          1          1          1
# 3995      4018    64385           0          1          1          1
# 3996      4019    73597           0          3          1          1
# 3997      4020    54899           0          1          1          1
# 3998      4021     3016           0          1          1          1
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0             174            1                  0                0
# ...

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data). Convert all data between 0 to 1 range to make it units free
airline_data_norm = norm_func(airline_data.iloc[:,1:-1])#Removed Award column as it is boolean
airline_data_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# ...

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(airline_data_norm, method='single'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=10, affinity = 'euclidean', linkage = 'single')

# %%
# save clusters for chart
y_hc = hc.fit_predict(airline_data_norm)
y_hc
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
airline_data['h_clusterid'] = hc.labels_
airline_data
# Out:
#       UniqueID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0            1    28143           0          1          1          1
# 1            2    19244           0          1          1          1
# 2            3    41354           0          1          1          1
# 3            4    14776           0          1          1          1
# 4            5    97752           0          4          1          1
# ...        ...      ...         ...        ...        ...        ...
# 3994      4017    18476           0          1          1          1
# 3995      4018    64385           0          1          1          1
# 3996      4019    73597           0          3          1          1
# 3997      4020    54899           0          1          1          1
# 3998      4021     3016           0          1          1          1
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0             174            1                  0                0
# ...

# %%
airline_data.sort_values(by=['h_clusterid','Flight_miles_12mo', 'Flight_trans_12', 'Balance','Days_since_enroll'], ascending=False)
# Out:
#       UniqueID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 904        915    15835           0          2          1          5
# 2999      3021   142527        1000          1          3          1
# 940        951    44824           0          1          3          1
# 2978      3000    22805           0          1          3          1
# 2166      2183   100634           0          1          3          1
# ...        ...      ...         ...        ...        ...        ...
# 3605      3628      265           0          1          1          1
# 1291      1304      249           0          1          1          1
# 2566      2585      199           0          1          1          1
# 553        559      148           0          1          1          1
# 2054      2071       68           0          1          1          1
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 904        112171           16                  0                0
# ...

# %%
#Divided into 10 clusters
